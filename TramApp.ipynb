# %%
import requests
import json
from datetime import datetime
from IPython.display import JSON, display

# %%
url = "https://v6.bvg.transport.rest/locations?poi=false&addresses=false&query=buschallee"

# %%
response = requests.get(url)

# %%
if response.status_code == 200:
    print(json.dumps(response.json(), indent=2))
else:
    print("Request failed:", response.status_code)
# Out:
# [
#   {
#     "type": "stop",
#     "id": "900140519",
#     "name": "Buschallee (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900140519",
#       "latitude": 52.553672,
#       "longitude": 13.469347
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900140519"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900140517",
#     "name": "Stadion Buschallee/Hansastr. (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900140517",
#       "latitude": 52.556908,
#       "longitude": 13.485986
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900140517"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900140007",
#     "name": "Hansastr./Buschallee (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900140007",
#       "latitude": 52.553168,
#       "longitude": 13.4807
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900140007"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900191504",
#     "name": "Eichbuschallee (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900191504",
#       "latitude": 52.475726,
#       "longitude": 13.487379
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": false,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900191504"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900191005",
#     "name": "Eichbuschallee/K\u00f6penicker Landstr. (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900191005",
#       "latitude": 52.474108,
#       "longitude": 13.483882
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": false,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900191005"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900080403",
#     "name": "Buschkrugallee/Parchimer Allee (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900080403",
#       "latitude": 52.445432,
#       "longitude": 13.454874
#     },
#     "products": {
#       "suburban": false,
#       "subway": true,
#       "tram": false,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900080403"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900230209",
#     "name": "Potsdam, Kirschallee",
#     "location": {
#       "type": "location",
#       "id": "900230209",
#       "latitude": 52.41388,
#       "longitude": 13.033307
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:12054:900230209"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900110001",
#     "name": "S+U Sch\u00f6nhauser Allee (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900110001",
#       "latitude": 52.549339,
#       "longitude": 13.415142
#     },
#     "products": {
#       "suburban": true,
#       "subway": true,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900110001"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900470268",
#     "name": "Cottbus, Stadthalle Puschkinpromenade",
#     "location": {
#       "type": "location",
#       "id": "900470268",
#       "latitude": 51.761668,
#       "longitude": 14.331008
#     },
#     "products": {
#       "suburban": false,
#       "subway": false,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:12052:900470268"
#     }
#   },
#   {
#     "type": "stop",
#     "id": "900120001",
#     "name": "S+U Frankfurter Allee (Berlin)",
#     "location": {
#       "type": "location",
#       "id": "900120001",
#       "latitude": 52.51358,
#       "longitude": 13.475846
#     },
#     "products": {
#       "suburban": true,
#       "subway": true,
#       "tram": true,
#       "bus": true,
#       "ferry": false,
#       "express": false,
#       "regional": false
#     },
#     "ids": {
#       "ifopt": "de:11000:900120001"
#     }
#   }
# ]

# %% [markdown]
# # IDs
# - Buschallee: 900140519
# - Weisser See: 900140006
# - Hackescher Markt: 900100002
# - Am Kupfergraben: 900100038
# - Virchow-Klinikum: 900010251
# - Warschauerstr: 900120011

# %%
stops = {"buschallee": 900140519,
         "weisser see": 900140006,
         "hackescher markt": 900100002,
         "am kupfergraben": 900100038,
         "virchow-klinikum": 900010251,
         "warschauerstr": 900120011
        }

# %%
#url = "https://v6.bvg.transport.rest/stops/{}/departures?results=10&bus=false"
url = "https://v6.bvg.transport.rest/stops/{}/departures?direction={}&duration=10"

# %%
response = requests.get(url.format(stops["buschallee"], stops["hackescher markt"]))

# %%
response = requests.get(url.format(stops["buschallee"]))

# %%
if response.status_code == 200:
    data = response.json()
    print(json.dumps(response.json(), indent=2))
else:
    print("Request failed:", response.status_code)
# Out:
# Request failed: 503

# %%
now = datetime.now(dt.tzinfo)
print(now)
# Out:
# 2026-05-29 08:57:30.181673+02:00

# %%
type(data)
# Out:
# dict

# %%
for item in data["departures"]:
    print(item["when"])
# Out:
# 2026-05-29T08:46:00+02:00
# 2026-05-29T08:50:00+02:00

# %%
display(JSON(data))

# %%
print(data["departures"][0]["line"]["name"])
print(data["departures"][0]["when"])
# Out:
# M4
# 2026-05-29T08:46:00+02:00

# %%
len(data["departures"])
# Out:
# 2

# %%
print(data["departures"][1]["line"]["name"])
print(data["departures"][1]["when"])
# Out:
# M4
# 2026-05-29T08:50:00+02:00

# %%
type(data["departures"][1]["when"])
# Out:
# str

# %%
dt = datetime.datetime.fromisoformat(data["departures"][0]["when"])

# %%
dt
# Out:
# datetime.datetime(2026, 5, 29, 8, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %%
delta = now - dt

# %%
minutes = (now - dt).total_seconds() / 60
print(minutes)
# Out:
# 11.503027883333335

# %%
when_str = data["departures"][0]["when"]
departure_time = datetime.fromisoformat(when_str)
now = datetime.now(departure_time.tzinfo)
minutes_until = (departure_time - now).total_seconds() / 60
print(f"Train arrives in {minutes_until:.1f} minutes")
# Out:
# Train arrives in -13.8 minutes
